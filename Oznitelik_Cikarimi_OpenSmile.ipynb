# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmetnihat/ses_analizi/blob/main/Oznitelik_Cikarimi_OpenSmile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opensmile
# Out:
# ...
#      |████████████████████████████████| 4.9 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 635 kB 51.0 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 167 kB 66.4 MB/s
# ...
#   Created wheel for iso-639: filename=iso_639-0.4.5-py3-none-any.whl size=169061 sha256=fcd6cde68e205fc10b7bd57338ad7f3a2b64f8fe8c1d7a38b0cae7bb99627472
#   Stored in directory: /root/.cache/pip/wheels/47/60/19/6d020fc92138ed1b113a18271e83ea4b5525fe770cb45b9a2e
# Successfully built iso-639
# ...

# %%
# !pip install pydub

# %%
from pydub import AudioSegment
dosya = os.scandir('/content/drive/MyDrive/Data/speech/tr/200adet/')
say = 0
for i in dosya:
  dosya_isim = i.name
  say = say + 1
  sound = AudioSegment.from_mp3('/content/drive/MyDrive/Data/speech/tr/200adet/' + dosya_isim)
  sound.export(f"/content/drive/MyDrive/Data/speech/tr/200adetwav/file{say}.wav", format="wav")

# %%
import os
import opensmile
import pandas as pd
import numpy
a=[]
eklenecekveri = pd.DataFrame(a)
s=[]
sonn = pd.DataFrame(s)

dizi= []
dosya = os.scandir('//content/drive/MyDrive/Data/ciglik/')
for i in dosya:
  dosya_isim = i.name
  b = []
  datas = pd.DataFrame(b)
  smile = opensmile.Smile(
      feature_set=opensmile.FeatureSet.ComParE_2016,
      feature_level=opensmile.FeatureLevel.Functionals,
  )
  y = smile.process_file('//content/drive/MyDrive/Data/ciglik/' + dosya_isim)
  print(y[:1])
  # dizi = y.to_numpy()
  # dt = pd.DataFrame(dizi)
  # print(dt)
  for a in dosya_isim:
  
    datas = y.assign(Duygu = "insanciglik")
  dosya_isim = eklenecekveri.append(datas)
  dizi.append(dosya_isim)


  sonhal = pd.concat(dizi)
  sonhal.to_csv("/content/drive/MyDrive/csvler/insanciglik.csv")

# %%
veris = pd.read_csv("/content/drive/MyDrive/csvler/kedi.csv")
veris1 = pd.read_csv("/content/drive/MyDrive/csvler/kopek.csv")
veris2 = pd.read_csv("/content/drive/MyDrive/csvler/insankonusma.csv")
veris4 = pd.read_csv("/content/drive/MyDrive/csvler/insanciglik.csv")
#veris5 = pd.read_csv("/content/drive/MyDrive/workspace/duyguverileri/sayisaldegerlimutsuz-memnuniyetsiz2.csv")
#veris6 = pd.read_csv("/content/drive/MyDrive/workspace/duyguverileri/sayisaldegerlimutlu2.csv")
#veris3 = pd.read_csv('/content/drive/MyDrive/testverilerimizmutsuz-memnuniyetsiz3335.csv')

verr = pd.concat([veris, veris1,veris2,veris4])

# %%
verr.to_csv("/content/drive/MyDrive/csvler/kedi_kopek_insankonusma_insanciglik.csv")

# %%
veris = pd.read_csv("/content/drive/MyDrive/csvler/kedi.csv")
veris1 = pd.read_csv("/content/drive/MyDrive/csvler/kopek.csv")

# %%
verr
# Out:
#                                                  file  ...        Duygu
# 0   /content/drive/MyDrive/Data/cats_and_dogs/cats...  ...         kedi
# 1   /content/drive/MyDrive/Data/cats_and_dogs/cats...  ...         kedi
# 2   /content/drive/MyDrive/Data/cats_and_dogs/cats...  ...         kedi
# 3   /content/drive/MyDrive/Data/cats_and_dogs/cats...  ...         kedi
# 4   /content/drive/MyDrive/Data/cats_and_dogs/cats...  ...         kedi
# ..                                                ...  ...          ...
# 65  //content/drive/MyDrive/Data/ciglik/Screaming ...  ...  insanciglik
# 66  //content/drive/MyDrive/Data/ciglik/Screaming ...  ...  insanciglik
# 67  //content/drive/MyDrive/Data/ciglik/Screaming ...  ...  insanciglik
# 68  //content/drive/MyDrive/Data/ciglik/Screaming ...  ...  insanciglik
# 69  //content/drive/MyDrive/Data/ciglik/Screaming ...  ...  insanciglik
#
# [597 rows x 6377 columns]

# %%
veris1
# Out:
#                                                   file  ...  Duygu
# 0    /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 1    /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 2    /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 3    /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 4    /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# ..                                                 ...  ...    ...
# 108  /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 109  /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 110  /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 111  /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
# 112  /content/drive/MyDrive/Data/cats_and_dogs/dogs...  ...  kopek
#
# [113 rows x 6377 columns]

# %%
import os
import opensmile
import pandas as pd
import numpy
a=[]
eklenecekveri = pd.DataFrame(a)
s=[]
sonn = pd.DataFrame(s)

dizi= []
dosya = os.scandir('/content/drive/MyDrive/Dataguncel/cats/')
for i in dosya:
  dosya_isim = i.name
  b = []
  datas = pd.DataFrame(b)
  smile = opensmile.Smile(
      feature_set=opensmile.FeatureSet.ComParE_2016,
      feature_level=opensmile.FeatureLevel.Functionals,
  )
  y = smile.process_file('/content/drive/MyDrive/Dataguncel/cats/' + dosya_isim)
  print(y[:1])
  # dizi = y.to_numpy()
  # dt = pd.DataFrame(dizi)
  # print(dt)
  for a in dosya_isim:
  
    datas = y.assign(Duygu = "cats")
  dosya_isim = eklenecekveri.append(datas)
  dizi.append(dosya_isim)


  sonhal = pd.concat(dizi)
  sonhal.to_csv("/content/drive/MyDrive/csvler/opensmile/cats.csv")
# Out:
# SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
#                                                                            audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                              ...
# /content/drive/MyDrive/Dataguncel/cats/cat_106.wav 0 days 0 days 00:00:12                         2.41079  ...                           48.284153
#
# [1 rows x 6373 columns]
#                                                                           audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                              start  end                                              ...
# ...

# %%
import os
import opensmile
import pandas as pd
import numpy
a=[]
eklenecekveri = pd.DataFrame(a)
s=[]
sonn = pd.DataFrame(s)

dizi= []
dosya = os.scandir('/content/drive/MyDrive/Dataguncel/ciglik/')
for i in dosya:
  dosya_isim = i.name
  b = []
  datas = pd.DataFrame(b)
  smile = opensmile.Smile(
      feature_set=opensmile.FeatureSet.ComParE_2016,
      feature_level=opensmile.FeatureLevel.Functionals,
  )
  y = smile.process_file('/content/drive/MyDrive/Dataguncel/ciglik/' + dosya_isim)
  print(y[:1])
  # dizi = y.to_numpy()
  # dt = pd.DataFrame(dizi)
  # print(dt)
  for a in dosya_isim:
  
    datas = y.assign(Duygu = "ciglik")
  dosya_isim = eklenecekveri.append(datas)
  dizi.append(dosya_isim)


  sonhal = pd.concat(dizi)
  sonhal.to_csv("/content/drive/MyDrive/csvler/opensmile/ciglik.csv")
# Out:
#                                                                                   audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                     ...
# /content/drive/MyDrive/Dataguncel/ciglik/QZXV_1... 0 days 0 days 00:00:02.820000                        3.585563  ...                          121.228218
#
# [1 rows x 6373 columns]
#                                                                                      audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                        ...
# /content/drive/MyDrive/Dataguncel/ciglik/A8AF_1... 0 days 0 days 00:00:02.490062500                        2.094662  ...                           55.347748
#
# [1 rows x 6373 columns]
# ...

# %%
import os
import opensmile
import pandas as pd
import numpy
a=[]
eklenecekveri = pd.DataFrame(a)
s=[]
sonn = pd.DataFrame(s)

dizi= []
dosya = os.scandir('/content/drive/MyDrive/Dataguncel/dogs/')
for i in dosya:
  dosya_isim = i.name
  b = []
  datas = pd.DataFrame(b)
  smile = opensmile.Smile(
      feature_set=opensmile.FeatureSet.ComParE_2016,
      feature_level=opensmile.FeatureLevel.Functionals,
  )
  y = smile.process_file('/content/drive/MyDrive/Dataguncel/dogs/' + dosya_isim)
  print(y[:1])
  # dizi = y.to_numpy()
  # dt = pd.DataFrame(dizi)
  # print(dt)
  for a in dosya_isim:
  
    datas = y.assign(Duygu = "dogs")
  dosya_isim = eklenecekveri.append(datas)
  dizi.append(dosya_isim)


  sonhal = pd.concat(dizi)
  sonhal.to_csv("/content/drive/MyDrive/csvler/opensmile/dogs.csv")
# Out:
#                                                                                      audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                        ...
# /content/drive/MyDrive/Dataguncel/dogs/dog_bark... 0 days 0 days 00:00:04.891562500                        4.198258  ...                           60.335957
#
# [1 rows x 6373 columns]
#                                                                                      audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                        ...
# /content/drive/MyDrive/Dataguncel/dogs/dog_bark... 0 days 0 days 00:00:02.494687500                        2.167104  ...                           52.618229
#
# [1 rows x 6373 columns]
# ...

# %%
import os
import opensmile
import pandas as pd
import numpy
a=[]
eklenecekveri = pd.DataFrame(a)
s=[]
sonn = pd.DataFrame(s)

dizi= []
dosya = os.scandir('/content/drive/MyDrive/Dataguncel/nefes/')
for i in dosya:
  dosya_isim = i.name
  b = []
  datas = pd.DataFrame(b)
  smile = opensmile.Smile(
      feature_set=opensmile.FeatureSet.ComParE_2016,
      feature_level=opensmile.FeatureLevel.Functionals,
  )
  y = smile.process_file('/content/drive/MyDrive/Dataguncel/nefes/' + dosya_isim)
  print(y[:1])
  # dizi = y.to_numpy()
  # dt = pd.DataFrame(dizi)
  # print(dt)
  for a in dosya_isim:
  
    datas = y.assign(Duygu = "nefes")
  dosya_isim = eklenecekveri.append(datas)
  dizi.append(dosya_isim)


  sonhal = pd.concat(dizi)
  sonhal.to_csv("/content/drive/MyDrive/csvler/opensmile/nefes.csv")
# Out:
#                                                                                      audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                        ...
# /content/drive/MyDrive/Dataguncel/nefes/J96S_3_... 0 days 0 days 00:00:02.763187500                         3.13676  ...                           38.699345
#
# [1 rows x 6373 columns]
#                                                                                   audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                     ...
# /content/drive/MyDrive/Dataguncel/nefes/TFA0_3_... 0 days 0 days 00:00:02.925750                        2.085637  ...                           53.272629
#
# [1 rows x 6373 columns]
# ...

# %%
import os
import opensmile
import pandas as pd
import numpy
a=[]
eklenecekveri = pd.DataFrame(a)
s=[]
sonn = pd.DataFrame(s)

dizi= []
dosya = os.scandir('/content/drive/MyDrive/Dataguncel/oksurme/')
for i in dosya:
  dosya_isim = i.name
  b = []
  datas = pd.DataFrame(b)
  smile = opensmile.Smile(
      feature_set=opensmile.FeatureSet.ComParE_2016,
      feature_level=opensmile.FeatureLevel.Functionals,
  )
  y = smile.process_file('/content/drive/MyDrive/Dataguncel/oksurme/' + dosya_isim)
  print(y[:1])
  # dizi = y.to_numpy()
  # dt = pd.DataFrame(dizi)
  # print(dt)
  for a in dosya_isim:
  
    datas = y.assign(Duygu = "oksurme")
  dosya_isim = eklenecekveri.append(datas)
  dizi.append(dosya_isim)


  sonhal = pd.concat(dizi)
  sonhal.to_csv("/content/drive/MyDrive/csvler/opensmile/oksurme.csv")
# Out:
#                                                                                   audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                     ...
# /content/drive/MyDrive/Dataguncel/oksurme/85OQ_... 0 days 0 days 00:00:02.580000                        3.401346  ...                           75.165436
#
# [1 rows x 6373 columns]
#                                                                                      audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                        ...
# /content/drive/MyDrive/Dataguncel/oksurme/OXPA_... 0 days 0 days 00:00:03.017062500                        4.147206  ...                           71.696579
#
# [1 rows x 6373 columns]
# ...

# %%
import os
import opensmile
import pandas as pd
import numpy
a=[]
eklenecekveri = pd.DataFrame(a)
s=[]
sonn = pd.DataFrame(s)

dizi= []
dosya = os.scandir('/content/drive/MyDrive/Dataguncel/200adetwav')
for i in dosya:
  dosya_isim = i.name
  b = []
  datas = pd.DataFrame(b)
  smile = opensmile.Smile(
      feature_set=opensmile.FeatureSet.ComParE_2016,
      feature_level=opensmile.FeatureLevel.Functionals,
  )
  
  y = smile.process_file('/content/drive/MyDrive/Dataguncel/200adetwav/' + dosya_isim)
  print(y[:1])
  # dizi = y.to_numpy()
  # dt = pd.DataFrame(dizi)
  # print(dt)
  for a in dosya_isim:
  
    datas = y.assign(Duygu = "human")
  dosya_isim = eklenecekveri.append(datas)
  dizi.append(dosya_isim)


  sonhal = pd.concat(dizi)
  sonhal.to_csv("/content/drive/MyDrive/csvler/opensmile/karisik200.csv")
# Out:
#                                                                                   audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                     ...
# /content/drive/MyDrive/Dataguncel/200adetwav/fi... 0 days 0 days 00:00:04.896000                        2.165251  ...                            74.52018
#
# [1 rows x 6373 columns]
#                                                                                   audspec_lengthL1norm_sma_range  ...  mfcc_sma_de[14]_stddevFallingSlope
# file                                               start  end                                                     ...
# /content/drive/MyDrive/Dataguncel/200adetwav/fi... 0 days 0 days 00:00:05.520000                        4.408391  ...                           50.812756
#
# [1 rows x 6373 columns]
# ...

# %%
veris1 = pd.read_csv("/content/drive/MyDrive/csvler/opensmile/dogs.csv")
veris2 = pd.read_csv("/content/drive/MyDrive/csvler/opensmile/nefes.csv")
veris4 = pd.read_csv("/content/drive/MyDrive/csvler/opensmile/karisik200.csv")
veris5 = pd.read_csv("/content/drive/MyDrive/csvler/opensmile/ciglik.csv")
veris6 = pd.read_csv("/content/drive/MyDrive/csvler/opensmile/oksurme.csv")

verr = pd.concat([veris, veris1,veris2,veris4,veris5,veris6])

# %%
verr.to_csv("/content/drive/MyDrive/csvler/opensmile/hepsi.csv")

# %%
verssis = pd.read_csv("/content/drive/MyDrive/csvler/librosasonmfcc40/7li.csv")
verssis.to_excel("sa.xlsx")

# %%
import os
from pydub import AudioSegment

path = "/content/drive/MyDrive/Dataguncel/karisik200"

#Change working directory
os.chdir(path)

audio_files = os.listdir()

# You dont need the number of files in the folder, just iterate over them directly using:
for file in audio_files:
    #spliting the file into the name and the extension
    name, ext = os.path.splitext(file)
    if ext == ".mp3":
       mp3_sound = AudioSegment.from_mp3(file)
       #rename them using the old name + ".wav"
       mp3_sound.export("/content/drive/MyDrive/Dataguncel/karisik200wav/{0}.wav".format(name), format="wav")
